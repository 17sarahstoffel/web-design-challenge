# %%
import pandas as pd

# %%
path = "Resources/weather_data.csv"

# %%
weather_df= pd.read_csv(path)
weather_df.head()
# Out:
#                        City  Latitude  Longitude  Max Temperature (F)  \
# 0                   Qaanaaq   77.4840   -69.3632                42.87
# 1               Cootamundra  -34.6500   148.0333                43.11
# 2                   Rikitea  -23.1203  -134.9692                72.91
# 3  São José da Coroa Grande   -8.8978   -35.1478                74.62
# 4                   Tubualá    9.5167   -79.0333                81.37
#
#    Humidity  Cloudiness  Wind Speed (mph) Country        Date
# 0        69         100             13.02      GL  1660426667
# 1        95         100              7.36      AU  1660426967
# 2        79          49             22.21      PF  1660426829
# 3        70          75             13.27      BR  1660426970
# 4        78         100              1.05      PA  1660426972

# %%
weather_html = weather_df.to_html()
weather_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Max Temperature (F)</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed (mph)</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Qaanaaq</td>\n      <td>77.4840</td>\n      <td>-69.3632</td>\n      <td>42.87</td>\n      <td>69</td>\n      <td>100</td>\n      <td>13.02</td>\n      <td>GL</td>\n      <td>1660426667</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Cootamundra</td>\n      <td>-34.6500</td>\n      <td>148.0333</td>\n      <td>43.11</td>\n      <td>95</td>\n      <td>100</td>\n      <td>7.36</td>\n      <td>AU</td>\n      <td>1660426967</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Rikitea</td>\n      <td>-23.1203</td>\n      <td>-134.9692</td>\n      <td>72.91</td>\n      <td>7
# ...

# %%
weather_df.to_html("Resources/weather.html")
